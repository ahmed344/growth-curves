# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Manipulate the curve

# %%
# Determine the Experiment and the GUV number
EXPERIMENT = '20220401_GUV_NTA2_on_DPPC2'
DATA = 'vesicle_1_(809-9999)-1'

# Read the curves as dataframes
df = pd.read_csv(f'Data/{EXPERIMENT}/{DATA}.csv')

# Subtractions
df['Area'][960:1665] = [x-y for x, y in zip(df['Area'][960:1665], np.linspace(10, 7, 1665-960))]
df['Area'][960:2405] = [x-y for x, y in zip(df['Area'][960:2405], np.linspace(0, 20, 2405-960))]


# Plot the curve
plt.figure(figsize=(15, 10))
plt.plot(df['Time'][:], df['Area'][:], label = f'{DATA}', color = 'b', alpha = 0.8)
plt.title(f'Area of the GUV {DATA}', fontsize= 'xx-large')
plt.xlabel('Time [ S ]', fontsize = "xx-large")
plt.ylabel('Area [ $\mu m^2$ ]', fontsize = "xx-large")
plt.xticks(fontsize = "xx-large")
plt.yticks(fontsize = "xx-large")
plt.grid(color = 'gray', alpha = 0.1)

# Save the figure into png
plt.savefig(f"Data/{EXPERIMENT}/{DATA}.png")

# Save the data into csv
df.to_csv(f"Data/{EXPERIMENT}/{DATA}.csv", index=False)

# %%
# Determine the Experiment and the GUV number
EXPERIMENT = '20220401_GUV_NTA2_on_DPPC2'
DATA = 'vesicle_1_(809-9999)-4'

# Read the curves as dataframes
df = pd.read_csv(f'Data/{EXPERIMENT}/{DATA}.csv')

# Subtractions
df['Area'][580:2025] = [x-y for x, y in zip(df['Area'][580:2025], np.linspace(2, 2.5, 2025-580))]
df['Area'][1060:2025] = [x-y for x, y in zip(df['Area'][1060:2025], np.linspace(1, 0, 2025-1060))]
df['Area'][2620:6240] = [x-y for x, y in zip(df['Area'][2620:6240], np.linspace(0, 1, 6240-2620))]


# Plot the curve
plt.figure(figsize=(15, 10))
plt.plot(df['Time'][:], df['Area'][:], label = f'{DATA}', color = 'b', alpha = 0.8)
plt.title(f'Area of the GUV {DATA}', fontsize= 'xx-large')
plt.xlabel('Time [ S ]', fontsize = "xx-large")
plt.ylabel('Area [ $\mu m^2$ ]', fontsize = "xx-large")
plt.xticks(fontsize = "xx-large")
plt.yticks(fontsize = "xx-large")
plt.grid(color = 'gray', alpha = 0.1)

# Save the figure into png
plt.savefig(f"Data/{EXPERIMENT}/{DATA}.png")

# Save the data into csv
df.to_csv(f"Data/{EXPERIMENT}/{DATA}.csv", index=False)

# %%
# Determine the Experiment and the GUV number
EXPERIMENT = '20220401_GUV_NTA2_on_DPPC2'
DATA = 'vesicle_2_MMStack_Default-1'

# Read the curves as dataframes
df = pd.read_csv(f'Data/{EXPERIMENT}/{DATA}.csv')

# Subtractions
df['Area'][1408:2370] = [x-y for x, y in zip(df['Area'][1408:2370], np.linspace(-5, -2, 2370-1408))]


# Plot the curve
plt.figure(figsize=(15, 10))
plt.plot(df['Time'][:], df['Area'][:], label = f'{DATA}', color = 'b', alpha = 0.8)
plt.title(f'Area of the GUV {DATA}', fontsize= 'xx-large')
plt.xlabel('Time [ S ]', fontsize = "xx-large")
plt.ylabel('Area [ $\mu m^2$ ]', fontsize = "xx-large")
plt.xticks(fontsize = "xx-large")
plt.yticks(fontsize = "xx-large")
plt.grid(color = 'gray', alpha = 0.1)

# Save the figure into png
plt.savefig(f"Data/{EXPERIMENT}/{DATA}.png")

# Save the data into csv
df.to_csv(f"Data/{EXPERIMENT}/{DATA}.csv", index=False)

# %%
# Determine the Experiment and the GUV number
EXPERIMENT = '20220415_GUV_NTA3_on_DPPC2'
DATA = 'vesicle_2_MMStack_Default-4'

# Read the curves as dataframes
df = pd.read_csv(f'Data/{EXPERIMENT}/{DATA}.csv')

# Subtractions
df['Area'][2222:2795] = [x-y for x, y in zip(df['Area'][2222:2795], np.linspace(0, 1.3, 2795-2222))]
# df['Area'][4000:7050] = [x-y for x, y in zip(df['Area'][4000:7050], np.linspace(0, 7, 7050-4000))]
# df['Area'][7100:8840] = [x-y for x, y in zip(df['Area'][7100:8840], np.linspace(0, 2, 8840-7100))]


# Plot the curve
plt.figure(figsize=(15, 10))
plt.plot(df['Time'][:], df['Area'][:], label = f'{DATA}', color = 'b', alpha = 0.8)
plt.title(f'Area of the GUV {DATA}', fontsize= 'xx-large')
plt.xlabel('Time [ S ]', fontsize = "xx-large")
plt.ylabel('Area [ $\mu m^2$ ]', fontsize = "xx-large")
plt.xticks(fontsize = "xx-large")
plt.yticks(fontsize = "xx-large")
plt.grid(color = 'gray', alpha = 0.1)

# Save the figure into png
plt.savefig(f"Data/{EXPERIMENT}/{DATA}.png")

# Save the data into csv
df.to_csv(f"Data/{EXPERIMENT}/{DATA}.csv", index=False)

# %%
# Determine the Experiment and the GUV number
EXPERIMENT = '20220719_GUV_NTA3_on_DPPC3'
DATA = 'vesicle_1_MMStack_Default.ome-1'

# Read the curves as dataframes
df = pd.read_csv(f'Data/{EXPERIMENT}/{DATA}.csv')

# Subtractions
df['Area'][665:1920] = [x-y for x, y in zip(df['Area'][665:1920], np.linspace(13, 7, 1920-665))]
df['Area'][4000:7050] = [x-y for x, y in zip(df['Area'][4000:7050], np.linspace(0, 7, 7050-4000))]
df['Area'][7100:8840] = [x-y for x, y in zip(df['Area'][7100:8840], np.linspace(0, 2, 8840-7100))]


# Plot the curve
plt.figure(figsize=(15, 10))
plt.plot(df['Time'][:], df['Area'][:], label = f'{DATA}', color = 'b', alpha = 0.8)
plt.title(f'Area of the GUV {DATA}', fontsize= 'xx-large')
plt.xlabel('Time [ S ]', fontsize = "xx-large")
plt.ylabel('Area [ $\mu m^2$ ]', fontsize = "xx-large")
plt.xticks(fontsize = "xx-large")
plt.yticks(fontsize = "xx-large")
plt.grid(color = 'gray', alpha = 0.1)

# Save the figure into png
plt.savefig(f"Data/{EXPERIMENT}/{DATA}.png")

# Save the data into csv
df.to_csv(f"Data/{EXPERIMENT}/{DATA}.csv", index=False)

# %%
# Determine the Experiment and the GUV number
EXPERIMENT = '20220719_GUV_NTA3_on_DPPC3'
DATA = 'vesicle_1_MMStack_Default.ome-3'

# Read the curves as dataframes
df = pd.read_csv(f'Data/{EXPERIMENT}/{DATA}.csv')

# Drope the errors
df = df.drop(range(900,970))
df = df[df['Area'] < 13]

# Subtractions
df['Area'][1000:3330] = [x-y for x, y in zip(df['Area'][1000:3330], np.linspace(0, 1.7, 3330-1000))]


# Plot the curve
plt.figure(figsize=(15, 10))
plt.plot(df['Time'][:], df['Area'][:], label = f'{DATA}', color = 'b', alpha = 0.8)
plt.title(f'Area of the GUV {DATA}', fontsize= 'xx-large')
plt.xlabel('Time [ S ]', fontsize = "xx-large")
plt.ylabel('Area [ $\mu m^2$ ]', fontsize = "xx-large")
plt.xticks(fontsize = "xx-large")
plt.yticks(fontsize = "xx-large")
plt.grid(color = 'gray', alpha = 0.1)

# Save the figure into png
plt.savefig(f"Data/{EXPERIMENT}/{DATA}.png")

# Save the data into csv
df.to_csv(f"Data/{EXPERIMENT}/{DATA}.csv", index=False)

# %%
# Determine the Experiment and the GUV number
EXPERIMENT = '20220719_GUV_NTA3_on_DPPC3'
DATA = 'vesicle_1_MMStack_Default.ome-5'

# Read the curves as dataframes
df = pd.read_csv(f'Data/{EXPERIMENT}/{DATA}.csv')

# Drope the errors
df = df.drop(range(2630,2700))

# Subtractions
df['Area'][2000:5060] = [x-y for x, y in zip(df['Area'][2000:5060], np.linspace(0, 2.7, 5060-2000))]
df['Area'][5060:6850] = [x-y for x, y in zip(df['Area'][5060:6850], np.linspace(0, 0.2, 6850-5060))]

# Remove some errors
df = df[df['Area'] < 12.5]

# Plot the curve
plt.figure(figsize=(15, 10))
plt.plot(df['Time'][:], df['Area'][:], label = f'{DATA}', color = 'b', alpha = 0.8)
plt.title(f'Area of the GUV {DATA}', fontsize= 'xx-large')
plt.xlabel('Time [ S ]', fontsize = "xx-large")
plt.ylabel('Area [ $\mu m^2$ ]', fontsize = "xx-large")
plt.xticks(fontsize = "xx-large")
plt.yticks(fontsize = "xx-large")
plt.grid(color = 'gray', alpha = 0.1)

# Save the figure into png
plt.savefig(f"Data/{EXPERIMENT}/{DATA}.png")

# Save the data into csv
df.to_csv(f"Data/{EXPERIMENT}/{DATA}.csv", index=False)

# %%
# Determine the Experiment and the GUV number
EXPERIMENT = '20220719_GUV_NTA3_on_DPPC3'
DATA = 'vesicle_7_MMStack_Default-1'

# Read the curves as dataframes
df = pd.read_csv(f'Data/{EXPERIMENT}/{DATA}.csv')

# # Subtractions
df['Area'][6230:8470] = [x-y for x, y in zip(df['Area'][6230:8470], np.linspace(0.9, 1.1, 8470-6230))]

# Drope the errors
df = df.drop(range(51,58))

# Plot the curve
plt.figure(figsize=(15, 10))
plt.plot(df['Time'][:], df['Area'][:], label = f'{DATA}', color = 'b', alpha = 0.8)
plt.title(f'Area of the GUV {DATA}', fontsize= 'xx-large')
plt.xlabel('Time [ S ]', fontsize = "xx-large")
plt.ylabel('Area [ $\mu m^2$ ]', fontsize = "xx-large")
plt.xticks(fontsize = "xx-large")
plt.yticks(fontsize = "xx-large")
plt.grid(color = 'gray', alpha = 0.1)

# Save the figure into png
plt.savefig(f"Data/{EXPERIMENT}/{DATA}.png")

# Save the data into csv
df.to_csv(f"Data/{EXPERIMENT}/{DATA}.csv", index=False)

# %%
# Determine the Experiment and the GUV number
EXPERIMENT = '20220719_GUV_NTA3_on_DPPC3'
DATA = 'vesicle_7_MMStack_Default-3'

# Read the curves as dataframes
df = pd.read_csv(f'Data/{EXPERIMENT}/{DATA}.csv')

# # Subtractions
df['Area'][4160:7746] = [x-y for x, y in zip(df['Area'][4160:7746], np.linspace(2.5, 2.2, 7746-4160))]

# Plot the curve
plt.figure(figsize=(15, 10))
plt.plot(df['Time'][:], df['Area'][:], label = f'{DATA}', color = 'b', alpha = 0.8)
plt.title(f'Area of the GUV {DATA}', fontsize= 'xx-large')
plt.xlabel('Time [ S ]', fontsize = "xx-large")
plt.ylabel('Area [ $\mu m^2$ ]', fontsize = "xx-large")
plt.xticks(fontsize = "xx-large")
plt.yticks(fontsize = "xx-large")
plt.grid(color = 'gray', alpha = 0.1)

# Save the figure into png
plt.savefig(f"Data/{EXPERIMENT}/{DATA}.png")

# Save the data into csv
df.to_csv(f"Data/{EXPERIMENT}/{DATA}.csv", index=False)

# %%
# Determine the Experiment and the GUV number
EXPERIMENT = '20220719_GUV_NTA3_on_DPPC3'
DATA = 'vesicle_7_MMStack_Default-4'

# Read the curves as dataframes
df = pd.read_csv(f'Data/{EXPERIMENT}/{DATA}.csv')

# # Subtractions
df['Area'][3310:6900] = [x-y for x, y in zip(df['Area'][3310:6900], np.linspace(2.3, 1.1, 6900-3310))]
df['Area'][5280:6705] = [x-y for x, y in zip(df['Area'][5280:6705], np.linspace(-0.4, 0.5, 6705-5280))]


# Plot the curve
plt.figure(figsize=(15, 10))
plt.plot(df['Time'][:], df['Area'][:], label = f'{DATA}', color = 'b', alpha = 0.8)
plt.title(f'Area of the GUV {DATA}', fontsize= 'xx-large')
plt.xlabel('Time [ S ]', fontsize = "xx-large")
plt.ylabel('Area [ $\mu m^2$ ]', fontsize = "xx-large")
plt.xticks(fontsize = "xx-large")
plt.yticks(fontsize = "xx-large")
plt.grid(color = 'gray', alpha = 0.1)

# Save the figure into png
plt.savefig(f"Data/{EXPERIMENT}/{DATA}.png")

# Save the data into csv
df.to_csv(f"Data/{EXPERIMENT}/{DATA}.csv", index=False)

# %%
# Determine the Experiment and the GUV number
EXPERIMENT = '20220719_GUV_NTA3_on_DPPC3'
DATA = 'vesicle_7_MMStack_Default-5'

# Read the curves as dataframes
df = pd.read_csv(f'Data/{EXPERIMENT}/{DATA}.csv')

# # Subtractions
df['Area'][783:2770] = [x-y for x, y in zip(df['Area'][783:2770], np.linspace(1, 0.2, 2770-783))]
df['Area'][783:4370] = [x-y for x, y in zip(df['Area'][783:4370], np.linspace(1.5, 0.9, 4370-783))]

# Plot the curve
plt.figure(figsize=(15, 10))
plt.plot(df['Time'][:], df['Area'][:], label = f'{DATA}', color = 'b', alpha = 0.8)
plt.title(f'Area of the GUV {DATA}', fontsize= 'xx-large')
plt.xlabel('Time [ S ]', fontsize = "xx-large")
plt.ylabel('Area [ $\mu m^2$ ]', fontsize = "xx-large")
plt.xticks(fontsize = "xx-large")
plt.yticks(fontsize = "xx-large")
plt.grid(color = 'gray', alpha = 0.1)

# Save the figure into png
plt.savefig(f"Data/{EXPERIMENT}/{DATA}.png")

# Save the data into csv
df.to_csv(f"Data/{EXPERIMENT}/{DATA}.csv", index=False)

# %%
# Determine the Experiment and the GUV number
EXPERIMENT = '20220719_GUV_NTA3_on_DPPC3'
DATA = 'vesicle_7_MMStack_Default-7'

# Read the curves as dataframes
df = pd.read_csv(f'Data/{EXPERIMENT}/{DATA}.csv')

# # Subtractions
df['Area'][1233:4820] = [x-y for x, y in zip(df['Area'][1233:4820], np.linspace(1.1, 0.4, 4820-1233))]

# Plot the curve
plt.figure(figsize=(15, 10))
plt.plot(df['Time'][:], df['Area'][:], label = f'{DATA}', color = 'b', alpha = 0.8)
plt.title(f'Area of the GUV {DATA}', fontsize= 'xx-large')
plt.xlabel('Time [ S ]', fontsize = "xx-large")
plt.ylabel('Area [ $\mu m^2$ ]', fontsize = "xx-large")
plt.xticks(fontsize = "xx-large")
plt.yticks(fontsize = "xx-large")
plt.grid(color = 'gray', alpha = 0.1)

# Save the figure into png
plt.savefig(f"Data/{EXPERIMENT}/{DATA}.png")

# Save the data into csv
df.to_csv(f"Data/{EXPERIMENT}/{DATA}.csv", index=False)

# %%
# Determine the Experiment and the GUV number
EXPERIMENT = '20220722_GUV_NTA3_on_DPPC3'
DATA = 'vesicle_9_MMStack_Default-1'

# Read the curves as dataframes
df = pd.read_csv(f'Data/{EXPERIMENT}/{DATA}.csv')

# # Subtractions
df['Area'][460:4250] = [x-y for x, y in zip(df['Area'][460:4250], np.linspace(50, 50, 4250-460))]
df['Area'][4250:7467] = [x-y for x, y in zip(df['Area'][4250:7467], np.linspace(8, -10, 7467-4250))]
df['Area'][5315:7095] = [x-y for x, y in zip(df['Area'][5315:7095], np.linspace(10, -15, 7095-5315))]

# Plot the curve
plt.figure(figsize=(15, 10))
plt.plot(df['Time'][:], df['Area'][:], label = f'{DATA}', color = 'b', alpha = 0.8)
plt.title(f'Area of the GUV {DATA}', fontsize= 'xx-large')
plt.xlabel('Time [ S ]', fontsize = "xx-large")
plt.ylabel('Area [ $\mu m^2$ ]', fontsize = "xx-large")
plt.xticks(fontsize = "xx-large")
plt.yticks(fontsize = "xx-large")
plt.grid(color = 'gray', alpha = 0.1)

# Save the figure into png
plt.savefig(f"Data/{EXPERIMENT}/{DATA}.png")

# Save the data into csv
df.to_csv(f"Data/{EXPERIMENT}/{DATA}.csv", index=False)

# %%
# Determine the Experiment and the GUV number
EXPERIMENT = '20220728_GUV_NTA5_on_BSABIO_antibody'
DATA = 'vesicle_3_MMStack_Default-1'

# Read the curves as dataframes
df = pd.read_csv(f'Data/{EXPERIMENT}/{DATA}.csv')

# # Subtractions
df['Area'][360:1657] = [x-y for x, y in zip(df['Area'][360:1657], np.linspace(2.3, 1.8, 1657-360))]

# Plot the curve
plt.figure(figsize=(15, 10))
plt.plot(df['Time'][:], df['Area'][:], label = f'{DATA}', color = 'b', alpha = 0.8)
plt.title(f'Area of the GUV {DATA}', fontsize= 'xx-large')
plt.xlabel('Time [ S ]', fontsize = "xx-large")
plt.ylabel('Area [ $\mu m^2$ ]', fontsize = "xx-large")
plt.xticks(fontsize = "xx-large")
plt.yticks(fontsize = "xx-large")
plt.grid(color = 'gray', alpha = 0.1)

# Save the figure into png
plt.savefig(f"Data/{EXPERIMENT}/{DATA}.png")

# Save the data into csv
df.to_csv(f"Data/{EXPERIMENT}/{DATA}.csv", index=False)

# %%
plt.plot(df['Area'][360:1657])
plt.grid()
